# %% [markdown]
# # Sckit Learn Pipelines
#
# Pipelinens chains together multiple  steps so that the output of each step is used as input to the next step
#
# pipelines makes it easy to apply the same preprocessing to train and test
