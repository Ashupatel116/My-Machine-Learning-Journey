# %% [markdown]
# ## 1.1 Missing values imputation

# %% [markdown]
# ## 1.2 Handling Categorical Data

# %% [markdown]
# ## 1.3 Outlier Detection

# %% [markdown]
# ## 1.4 Feature detection

# %% [markdown]
# ## 3 Feature Selection

# %% [markdown]
# ## 2 Feature Cunstruction

# %% [markdown]
# ## 4 Feature Exactration
